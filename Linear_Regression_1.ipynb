# %% [markdown]
# # predict student marks based on study houras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
data = {"Hours": [1,2,3,4,5,6,7,8,9]
       , "Marks": [10,20,30,40,50,60,75,85,95]}

# %%
df = pd.DataFrame(data)

# %%
X = df[["Hours"]]
y = df["Marks"]

# %%
model = LinearRegression()
model.fit(X , y)
# Out:
# LinearRegression()

# %%
predict = model.predict([[7]])
print("Predicted Marks : ", predict[0])
# Out:
# Predicted Marks :  73.16666666666666
# C:\Users\prajy\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y, color="blue", label="Actual Data")
plt.plot(X, model.predict(X), color="red", label="Regression Line")
plt.xlabel("Hours Studied")
plt.ylabel("Marks Scored")
plt.legend()
plt.show()
